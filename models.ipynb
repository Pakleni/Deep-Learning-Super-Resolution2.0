# %%
from dlsr import *

image_size = 32

# %%
models.generator(B=16).summary()
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
# 2023-01-30 01:17:03.673311: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-30 01:17:03.673596: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d (Conv2D)                (None, None, None,   15616       ['input_1[0][0]']
# ...

# %%
models.discriminator(image_size=image_size).summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_36 (Conv2D)          (None, 32, 32, 64)        1792
#
#  leaky_re_lu (LeakyReLU)     (None, 32, 32, 64)        0
#
#  conv2d_37 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization (BatchN  (None, 16, 16, 64)       256
#  ormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 16, 16, 64)        0
#
#  conv2d_38 (Conv2D)          (None, 16, 16, 128)       73856
#
#  batch_normalization_1 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 16, 16, 128)       0
#
#  conv2d_39 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_2 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 8, 8, 128)         0
#
# ...
