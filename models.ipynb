# %%
from dlsr import *

image_size = 96

# %%
models.generator(B=16, scale=2).summary()
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
# 2023-02-04 01:19:42.709361: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-02-04 01:19:42.709387: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d (Conv2D)                (None, None, None,   15616       ['input_1[0][0]']
# ...

# %%
models.generator(B=16, scale=4).summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d_36 (Conv2D)             (None, None, None,   15616       ['input_2[0][0]']
#                                 64)
#
#  p_re_lu_18 (PReLU)             (None, None, None,   64          ['conv2d_36[0][0]']
#                                 64)
#
#  conv2d_37 (Conv2D)             (None, None, None,   36928       ['p_re_lu_18[0][0]']
#                                 64)
#
#  batch_normalization_33 (BatchN  (None, None, None,   256        ['conv2d_37[0][0]']
#  ormalization)                  64)
#
#  p_re_lu_19 (PReLU)             (None, None, None,   64          ['batch_normalization_33[0][0]']
#                                 64)
#
# ...

# %%
models.discriminator(image_size=image_size).summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_3 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  conv2d_73 (Conv2D)          (None, 96, 96, 64)        1792
#
#  leaky_re_lu (LeakyReLU)     (None, 96, 96, 64)        0
#
#  conv2d_74 (Conv2D)          (None, 48, 48, 64)        36928
#
#  batch_normalization_66 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 48, 48, 64)        0
#
#  conv2d_75 (Conv2D)          (None, 48, 48, 128)       73856
#
#  batch_normalization_67 (Bat  (None, 48, 48, 128)      512
#  chNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 48, 48, 128)       0
#
#  conv2d_76 (Conv2D)          (None, 24, 24, 128)       147584
#
#  batch_normalization_68 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 24, 24, 128)       0
#
# ...
